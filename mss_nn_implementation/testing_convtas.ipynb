# %%
import numpy as np
import datasets
import tensorflow as tf
from tensorflow.keras import activations, layers, models, metrics
import matplotlib.pyplot as plt
from parameters import Parameters
import convtas
from loss import LOGL2,SDR,SISNR,SDSDR,SISDR

# %% [markdown]
# First thing we are going to do is to just load our data in. The data when being put through a TensorFlow should be organized in a very specific way. Right now each observation in our data is organized like this : $(2\cdot M,K,L)$
#
# - $M$ = 100; Batch number, remember each batch observation is 2 tensors each one correlating to the left/right audio channel.
# - $K$ = 40; Index/number of overlapping chunks of waveform.
# - $L$ = 16; Length of a chunk/sample of data. For this study we will refer to these as chunks.
#
# For our outputs the data is structured like: $(2\cdot M,C,K,L)$
#
# - $C$ = 4; Denotes the source target.

# %%
arr = np.array(range(5))
len(arr)
# Out:
# 5

# %%
arr[5:]
# Out:
# array([], dtype=int32)

# %%
loss = SDSDR()
loss(x,y)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=-58.575706>

# %%
M, C = alpha.shape
alpha = tf.reshape(alpha, (M, C, 1))

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# Num GPUs Available:  1

# %%
def make_med_dataset():
    datasets = [tf.data.Dataset.load(f'tensors/tensor_dataset_small_{i}') for i in range(10)]

    for i, data in enumerate(datasets):
        if i == 0:
            dataset = data
        else: 
            dataset = dataset.concatenate(data)
    
    dataset.save('tensors/tensor_dataset_medium')

make_med_dataset()

# %%
dataset = tf.data.Dataset.load(f'data_v2/tensor_full_no1')

# %%
dataset_small = tf.data.Dataset.load(f'data_v2/tensor_test_8')

# %%
for i, batch in enumerate(dataset):
    if i==0:
        x_0,y_0 = batch
    break
x_0.shape
# Out:
# TensorShape([100, 400])

# %%
print(tf.data.experimental.cardinality(dataset).numpy())
# Out:
# 9099

# %%
param = Parameters(casual=False)

# %%
cnn = convtas.ConvTasNet(param)

# %%
cnn.load_weights('training_final_full/cp.ckpt')

# %%
output_x_0 = cnn(x_0)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Conv._jit_compiled_convolution_op at 0x00000234DDE73CA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Conv._jit_compiled_convolution_op at 0x00000234DF2B14C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
output_x_0.shape
# Out:
# TensorShape([50, 4, 4000])

# %%
y_0.shape
# Out:
# TensorShape([50, 4, 4000])

# %% [markdown]
# ok so the issue here is that i am running out of memory within my gpu. so i can do a couple of different things. First off this is strange as i feel like it did train on data with higher amounts of data than this but maybe i am incorrect as that would be like what 17000x40x512 which is maybe lower than 200x3999x128

# %%
def run_model(model, loss: str, loss_funct, dataset, epochs=10):
    # Create a callback that saves the model's weights every 5 epochs
    checkpoint_path = f"training_{loss}_2/cp.ckpt"
    checkpoint_dir = os.path.dirname(checkpoint_path)

    # Create a callback that saves the model's weights
    cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                    save_weights_only=True,
                                                    verbose=1)
    
    model.compile(optimizer='adam',
              loss=loss_funct,
              metrics=['accuracy']
              )
    
    history = model.fit(dataset, epochs=epochs, callbacks=[cp_callback])

    return history

def create_fit_save(dataset, epochs=10):
    param = Parameters()
    cnn = convtas.ConvTasNet(param)
    v
    hist1 = run_model(cnn, "LOGL2", LOGL2(), dataset, epochs=8)
    cnn = convtas.ConvTasNet(param)
    hist2 = run_model(cnn, "SDR", SDR(), dataset)
    
    return hist1, hist2

# %%
import tensorflow as tf

# Assuming 'model' is your compiled model and 'data' is your input tensor
with tf.GradientTape() as tape:
    output = cnn(x_0)
    loss = tf.reduce_mean(output)  # Example loss function

# Get the gradients
grads = tape.gradient(loss, cnn.trainable_variables)

# Print out gradients to see if they exist
for grad, var in zip(grads, cnn.trainable_variables):
    if grad is None:
        print(f"No gradient for {var.name}")
    else:
        print(f"Gradient for {var.name} exists")
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Conv._jit_compiled_convolution_op at 0x0000016460A45DA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Conv._jit_compiled_convolution_op at 0x0000016642F85C60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Gradient for ConvTasNet/Encoder/conv1d/kernel:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/conv1d_1/kernel:0 exists
# Gradient for ConvTasNet/Separator/conv1d_1/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_2/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_2/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_3/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_3/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_1/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_1/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_1/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_4/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_4/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_2/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_5/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_5/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_3/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_2/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_2/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_3/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_3/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_6/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_6/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_4/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_7/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_7/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_5/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_4/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_4/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_5/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_5/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_8/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_8/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_6/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_9/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_9/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_7/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_6/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_6/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_7/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_7/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_10/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_10/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_8/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_11/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_11/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_9/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_8/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_8/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_9/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_9/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_12/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_12/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_10/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_13/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_13/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_11/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_10/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_10/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_11/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_11/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_14/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_14/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_12/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_15/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_15/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_13/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_12/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_12/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_13/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_13/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_16/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_16/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_14/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_17/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_17/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_15/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_14/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_14/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_15/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_15/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_18/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_18/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_16/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_19/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_19/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_17/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_16/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_16/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_17/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_17/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_20/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_20/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_18/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_21/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_21/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_19/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_18/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_18/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_19/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_19/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_22/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_22/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_20/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_23/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_23/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_21/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_20/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_20/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_21/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_21/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_24/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_24/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_22/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_25/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_25/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_23/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_22/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_22/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_23/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_23/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_26/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_26/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_24/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_27/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_27/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_25/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_24/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_24/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_25/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_25/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_28/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_28/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_26/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_29/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_29/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_27/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_26/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_26/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_27/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_27/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_30/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_30/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_28/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_31/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_31/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_29/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_28/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_28/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_29/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_29/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_32/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_32/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_30/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_33/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_33/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_31/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_30/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_30/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_31/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_31/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_34/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_34/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_32/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_35/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_35/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_33/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_32/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_32/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_33/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_33/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_36/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_36/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_34/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_37/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_37/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_35/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_34/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_34/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_35/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_35/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_38/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_38/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_36/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_39/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_39/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_37/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_36/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_36/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_37/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_37/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_40/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_40/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_38/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_41/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_41/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_39/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_38/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_38/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_39/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_39/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_42/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_42/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_40/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_43/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_43/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_41/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_40/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_40/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_41/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_41/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_44/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_44/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_42/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_45/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_45/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_43/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_42/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_42/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_43/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_43/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_46/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_46/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_44/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_47/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_47/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_45/alpha:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_44/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_44/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_45/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_45/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_48/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/conv1d_48/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/p_re_lu_46/alpha:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for Global Gamma:0 exists
# Gradient for Global Beta:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_49/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_49/bias:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/p_re_lu_47/alpha:0 exists
# No gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_46/kernel:0
# No gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_46/bias:0
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_47/kernel:0 exists
# Gradient for ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_47/bias:0 exists
# Gradient for ConvTasNet/Separator/p_re_lu_48/alpha:0 exists
# Gradient for ConvTasNet/Separator/conv1d_50/kernel:0 exists
# Gradient for ConvTasNet/Separator/conv1d_50/bias:0 exists
# Gradient for ConvTasNet/Decoder/conv1d_transpose/kernel:0 exists

# %%
param = Parameters(casual=False)

# %%
y_0
# Out:
# <tf.Tensor: shape=(50, 4, 1200), dtype=float32, numpy=
# array([[[-3.35302507e-03, -3.35302507e-03, -3.35302507e-03, ...,
#          -3.35302507e-03, -3.35302507e-03, -3.35302507e-03],
#         [-4.89951903e-03, -3.86852305e-03, -3.35302507e-03, ...,
#          -3.35302507e-03, -3.86852305e-03, -3.86852305e-03],
#         [-3.35302507e-03, -3.35302507e-03, -3.35302507e-03, ...,
#          -3.35302507e-03, -3.35302507e-03, -3.35302507e-03],
#         [-1.88179668e-02, -1.72714721e-02, -1.52094802e-02, ...,
#           8.50343052e-03,  1.26274154e-02,  1.46894073e-02]],
#
#        [[-3.35302507e-03, -3.35302507e-03, -3.35302507e-03, ...,
#          -3.35302507e-03, -3.35302507e-03, -3.35302507e-03],
#         [-3.35302507e-03, -3.35302507e-03, -2.83752684e-03, ...,
#          -2.32202886e-03, -2.32202886e-03, -1.80653075e-03],
#         [-3.35302507e-03, -3.35302507e-03, -3.35302507e-03, ...,
#          -3.35302507e-03, -3.35302507e-03, -3.35302507e-03],
#         [-2.24264525e-02, -2.08799597e-02, -1.72714721e-02, ...,
#           2.83295196e-03,  4.89494391e-03,  7.98793230e-03]],
#
#        [[-5.90268150e-02,  1.90989748e-01,  2.38415569e-01, ...,
#          -5.18098436e-02,  8.73746350e-02,  1.64699346e-01],
#         [ 5.64447492e-02,  6.98477030e-02, -2.39729472e-02, ...,
#           2.40993053e-01, -7.96467364e-02,  1.93288904e-02],
#         [-1.79137871e-01, -1.56971455e-01, -1.35320529e-01, ...,
#          -1.10961187e+00, -1.14982069e+00, -1.17971957e+00],
#         [-3.01826417e-01, -3.05434883e-01, -2.12645233e-01, ...,
#           1.18304521e-01,  2.01815203e-01,  2.69345462e-01]],
#
#        ...,
#
#        [[-5.53904951e-01, -4.36886907e-01, -4.35340405e-01, ...,
#          -1.34622550e+00, -2.79374409e+00, -3.17933655e+00],
#         [-4.17297959e-01, -3.20384324e-01, -4.31216419e-01, ...,
#           1.02324076e-01,  7.65491724e-02,  2.70891935e-01],
#         [ 4.07498926e-01,  4.19870883e-01,  4.38428819e-01, ...,
#          -1.98489632e-02, -1.67559739e-02, -1.36629865e-02],
#         [-1.06476355e+00, -8.79699707e-01, -1.02403915e+00, ...,
#          -1.26993179e+00, -8.08561027e-01, -3.86883587e-01]],
#
#        [[-3.32934666e+00, -5.09905148e+00, -3.40488762e-01, ...,
#           1.37251127e+00, -1.04569006e+00, -2.91127753e+00],
#         [-2.75817466e+00, -2.73549271e+00, -2.78034115e+00, ...,
#           8.53126422e-02, -3.27364132e-02, -3.76058131e-01],
#         [-1.23797095e+00, -1.28591216e+00, -1.17095613e+00, ...,
#          -1.33127606e+00, -9.84345853e-01, -6.33807182e-01],
#         [-1.85323849e-01, -1.82230860e-01,  1.18820019e-01, ...,
#           7.99277484e-01,  3.27596724e-01,  8.10618401e-01]],
#
#        [[-3.67473030e+00, -4.78665972e+00,  2.04908192e-01, ...,
#           1.53437769e+00, -1.02558565e+00, -2.96437383e+00],
#         [-2.73136878e+00, -2.65971446e+00, -2.69734597e+00, ...,
#           1.33769467e-01,  5.95377386e-02, -4.13173974e-01],
#         [-8.99804175e-01, -9.41044033e-01, -8.65265787e-01, ...,
#          -9.71458375e-01, -7.19379842e-01, -4.65239286e-01],
#         [ 4.76812832e-02,  3.97188962e-01,  5.28125465e-01, ...,
#           1.04517007e+00,  3.34844994e-03,  3.04399312e-01]]],
#       dtype=float32)>

# %%
class GradientMonitor(tf.keras.callbacks.Callback):
    def on_batch_end(self, batch, logs=None):
        for layer in self.model.layers:
            if hasattr(layer, 'kernel'):
                grads = self.model.optimizer.get_gradients(self.model.total_loss, layer.kernel)
                grads_values = [g.numpy() for g in grads if g is not None]
                if grads_values:
                    max_grad = np.max([np.max(g) for g in grads_values])
                    min_grad = np.min([np.min(g) for g in grads_values])
                    print(f'{layer.name} - Max grad: {max_grad}, Min grad: {min_grad}')

# %%
checkpoint_path = f"training_final_full_no1/cp.ckpt"

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                    save_weights_only=True,
                                                    verbose=1)
cnn = convtas.ConvTasNet(param)

cnn.compile(optimizer=tf.keras.optimizers.Adam(),
            loss='mse',
            metrics=['accuracy', SDSDR(), SISDR(), LOGL2(), 'cosine_similarity'])

history = cnn.fit(dataset, epochs=2, callbacks=[GradientMonitor(),cp_callback])
# Out:
# Epoch 1/2
# WARNING:tensorflow:Gradients do not exist for variables ['ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_94/kernel:0', 'ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_94/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_94/kernel:0', 'ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/dense_94/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 9004/9004 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.0789 - sdsdr: inf - sisdr: inf - logl2: -inf - cosine_similarity: 0.4433
# Epoch 1: saving model to training_final_full_no1\cp.ckpt
# 9004/9004 [==============================] - 3779s 417ms/step - loss: 0.0020 - accuracy: 0.0789 - sdsdr: inf - sisdr: inf - logl2: -inf - cosine_similarity: 0.4433
# Epoch 2/2
# 9004/9004 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.0809 - sdsdr: inf - sisdr: inf - logl2: -inf - cosine_similarity: 0.4460
# Epoch 2: saving model to training_final_full_no1\cp.ckpt
# 9004/9004 [==============================] - 3854s 428ms/step - loss: 0.0019 - accuracy: 0.0809 - sdsdr: inf - sisdr: inf - logl2: -inf - cosine_similarity: 0.4460

# %%
for i, batch in enumerate(dataset_small):
    if i==77:
        x_0,y_0 = batch
        break
x_0.shape
# Out:
# TensorShape([100, 400])

# %%
np.all(np.array(x_0[1])==0.0)
# Out:
# False

# %%
y_0
# Out:
# <tf.Tensor: shape=(100, 4, 400), dtype=float32, numpy=
# array([[[-1.19934082e-02, -2.23388672e-02, -1.71508789e-02, ...,
#          -6.01196289e-03,  7.32421875e-04, -4.03442383e-02],
#         [ 1.21337891e-01,  1.12304688e-01,  1.22375488e-01, ...,
#           4.99877930e-02,  4.58679199e-02,  5.11169434e-02],
#         [ 2.34985352e-03,  3.02124023e-03,  4.97436523e-03, ...,
#          -1.11389160e-01, -1.03973389e-01, -9.60388184e-02],
#         [ 8.04138184e-02,  9.32922363e-02,  8.75244141e-02, ...,
#           4.27246094e-03, -7.29370117e-03, -7.09228516e-02]],
#
#        [[ 3.31420898e-02,  5.73730469e-03, -1.98364258e-02, ...,
#          -7.62939453e-03, -9.91821289e-03, -3.49121094e-02],
#         [ 9.30786133e-02,  8.39843750e-02,  9.28039551e-02, ...,
#           6.16760254e-02,  8.36791992e-02,  9.51843262e-02],
#         [ 1.10656738e-01,  1.11114502e-01,  1.11206055e-01, ...,
#          -1.10504150e-01, -9.97924805e-02, -8.87145996e-02],
#         [ 3.08532715e-02,  4.06494141e-02,  3.39355469e-02, ...,
#           2.29492188e-02,  1.08032227e-02, -3.75671387e-02]],
#
#        [[-3.50952148e-03,  4.35485840e-02,  3.64990234e-02, ...,
#           1.97143555e-02,  2.56958008e-02,  2.73132324e-02],
#         [ 4.63867188e-02,  5.28564453e-02,  5.21545410e-02, ...,
#           1.93176270e-02,  3.01208496e-02,  3.45458984e-02],
#         [-8.80432129e-02, -8.01391602e-02, -7.23266602e-02, ...,
#           1.77917480e-02,  1.62353516e-02,  1.45874023e-02],
#         [-3.52172852e-02, -2.94799805e-02, -4.47998047e-02, ...,
#           7.16552734e-02,  7.42187500e-02,  7.81860352e-02]],
#
#        ...,
#
#        [[-3.65905762e-02,  1.00708008e-03, -9.17053223e-02, ...,
#          -2.19116211e-02, -4.09851074e-02, -5.68237305e-02],
#         [ 6.39343262e-02,  6.29882812e-02,  6.82983398e-02, ...,
#           7.76977539e-02,  8.02001953e-02,  7.92541504e-02],
#         [ 3.37524414e-02,  3.56445312e-02,  3.74145508e-02, ...,
#          -8.81042480e-02, -8.79821777e-02, -8.77075195e-02],
#         [ 3.65295410e-02,  3.42407227e-02,  3.12805176e-02, ...,
#          -2.19421387e-02, -5.60607910e-02, -7.38830566e-02]],
#
#        [[-6.88171387e-02, -8.74938965e-02, -1.00280762e-01, ...,
#          -6.10351562e-05, -4.45556641e-03, -1.72119141e-02],
#         [ 4.91333008e-03,  5.61523438e-03,  8.17871094e-03, ...,
#           6.62231445e-03,  7.84301758e-03,  8.69750977e-03],
#         [-5.83190918e-02, -5.48706055e-02, -5.10864258e-02, ...,
#          -6.12487793e-02, -6.41784668e-02, -6.58874512e-02],
#         [-4.87060547e-02, -3.24707031e-02, -1.80053711e-02, ...,
#           1.13220215e-02,  1.41296387e-02,  2.22778320e-03]],
#
#        [[-6.63757324e-02, -7.11059570e-02, -7.53173828e-02, ...,
#          -4.67224121e-02, -5.44128418e-02, -8.19702148e-02],
#         [ 7.90405273e-02,  8.03222656e-02,  7.99865723e-02, ...,
#           6.08825684e-02,  6.31103516e-02,  6.32934570e-02],
#         [-8.72802734e-02, -8.66699219e-02, -8.58154297e-02, ...,
#          -1.51062012e-02, -2.00500488e-02, -2.40478516e-02],
#         [-5.00793457e-02, -3.19213867e-02, -2.91442871e-02, ...,
#           2.12097168e-02,  2.59094238e-02,  6.13403320e-03]]],
#       dtype=float32)>

# %%
x_0_out = cnn(x_0)
x_0_out
# Out:
# <tf.Tensor: shape=(100, 4, 400), dtype=float32, numpy=
# array([[[ 0.01557349,  0.02460878,  0.01880575, ..., -0.00491433,
#          -0.00279828, -0.01316455],
#         [ 0.0406733 ,  0.04880733,  0.05002109, ..., -0.01456681,
#          -0.01383783, -0.01604015],
#         [ 0.02311576,  0.02158137,  0.02648826, ..., -0.0190702 ,
#          -0.01730613, -0.01858684],
#         [ 0.01905023,  0.02404152,  0.02545515, ..., -0.02194034,
#          -0.02393191, -0.02463853]],
#
#        [[ 0.03011879,  0.03612752,  0.01894012, ...,  0.01514366,
#           0.01623222,  0.01278587],
#         [ 0.04338653,  0.04255102,  0.0379236 , ..., -0.02100557,
#          -0.01663773, -0.0183784 ],
#         [ 0.03529071,  0.03286241,  0.03560761, ..., -0.03267335,
#          -0.02967654, -0.02767049],
#         [ 0.03078405,  0.035926  ,  0.03474029, ...,  0.00263119,
#           0.00248265, -0.00287955]],
#
#        [[-0.02881642, -0.01966633, -0.0236802 , ...,  0.01904036,
#           0.02295856,  0.02668016],
#         [-0.01522717, -0.00849543, -0.00684774, ...,  0.00594243,
#           0.00703737,  0.00956028],
#         [ 0.00954226,  0.01367686,  0.01434228, ..., -0.00060211,
#          -0.00085976,  0.00353472],
#         [ 0.01206641,  0.01773866,  0.02092332, ...,  0.03406866,
#           0.03431255,  0.03352179]],
#
#        ...,
#
#        [[ 0.02464528,  0.03214032,  0.01177942, ..., -0.02140878,
#          -0.03712888, -0.03884914],
#         [ 0.00845957,  0.01148118,  0.00450178, ..., -0.00040492,
#          -0.00217186, -0.00625467],
#         [ 0.01535942,  0.01673941,  0.01675799, ...,  0.00226952,
#           0.00097346, -0.00107892],
#         [ 0.01893232,  0.02341485,  0.02205122, ..., -0.01203319,
#          -0.01801036, -0.01996465]],
#
#        [[-0.02225769, -0.02248157, -0.02231042, ..., -0.00826275,
#          -0.01369398, -0.01476597],
#         [-0.04134179, -0.04004668, -0.03426678, ...,  0.00015732,
#          -0.00082647, -0.00271878],
#         [-0.010195  , -0.01121927, -0.00936219, ...,  0.00335357,
#           0.00274363,  0.0019007 ],
#         [-0.00498797, -0.00310813,  0.00235297, ..., -0.00832611,
#          -0.01090729, -0.01111788]],
#
#        [[-0.0197868 , -0.02035748, -0.02110027, ..., -0.00884013,
#          -0.01627481, -0.01898215],
#         [-0.02968594, -0.02801649, -0.02415439, ...,  0.01924981,
#           0.01699786,  0.01269705],
#         [-0.00805625, -0.00699327, -0.00624077, ...,  0.02719827,
#           0.02378306,  0.02267755],
#         [-0.00451229, -0.00263399,  0.00049473, ...,  0.00487699,
#           0.00152736, -0.0001    ]]], dtype=float32)>

# %%
# Output for sisnr trained model for five epochs
fig, axes = plt.subplots(1,4, figsize=(12,4))
sources = ["Drums", "Bass", "Other", "Vocals"]

for i in range(4):
    axes[i].plot(x_0[0], label="Orignal Mix")
    axes[i].plot(y_0[0][i], label=f"Source")
    axes[i].plot(x_0_out[0][i], label=f"Source Est")

    if i==0:
        fig.legend()

    axes[i].set_title(f"Source: {sources[i]}")

# %%
# Output for sisnr trained model for five epochs
fig, axes = plt.subplots(1,4, figsize=(12,4))
sources = ["Drums", "Bass", "Other", "Vocals"]

for i in range(4):

    axes[i].plot(y_0[0][i], label=f"Source")


    if i==0:
        fig.legend()

    axes[i].set_title(f"Source: {sources[i]}")

# %%
N = 1840
starts = list(range(0,N,9))
starts
# Out:
# [0,
#  9,
#  18,
#  27,
#  36,
#  45,
#  54,
#  63,
#  72,
#  81,
#  90,
#  99,
#  108,
#  117,
#  126,
#  135,
#  144,
#  153,
#  162,
#  171,
#  180,
#  189,
#  198,
#  207,
#  216,
#  225,
#  234,
#  243,
#  252,
#  261,
#  270,
#  279,
#  288,
#  297,
#  306,
#  315,
#  324,
#  333,
#  342,
#  351,
#  360,
#  369,
#  378,
#  387,
#  396,
#  405,
#  414,
#  423,
#  432,
#  441,
#  450,
#  459,
#  468,
#  477,
#  486,
#  495,
#  504,
#  513,
#  522,
#  531,
#  540,
#  549,
#  558,
#  567,
#  576,
#  585,
#  594,
#  603,
#  612,
#  621,
#  630,
#  639,
#  648,
#  657,
#  666,
#  675,
#  684,
#  693,
#  702,
#  711,
#  720,
#  729,
#  738,
#  747,
#  756,
#  765,
#  774,
#  783,
#  792,
#  801,
#  810,
#  819,
#  828,
#  837,
#  846,
#  855,
#  864,
#  873,
#  882,
#  891,
#  900,
#  909,
#  918,
#  927,
#  936,
#  945,
#  954,
#  963,
#  972,
#  981,
#  990,
#  999,
#  1008,
#  1017,
#  1026,
#  1035,
#  1044,
#  1053,
#  1062,
#  1071,
#  1080,
#  1089,
#  1098,
#  1107,
#  1116,
#  1125,
#  1134,
#  1143,
#  1152,
#  1161,
#  1170,
#  1179,
#  1188,
#  1197,
#  1206,
#  1215,
#  1224,
#  1233,
#  1242,
#  1251,
#  1260,
#  1269,
#  1278,
#  1287,
#  1296,
#  1305,
#  1314,
#  1323,
#  1332,
#  1341,
#  1350,
#  1359,
#  1368,
#  1377,
#  1386,
#  1395,
#  1404,
#  1413,
#  1422,
#  1431,
#  1440,
#  1449,
#  1458,
#  1467,
#  1476,
#  1485,
#  1494,
#  1503,
#  1512,
#  1521,
#  1530,
#  1539,
#  1548,
#  1557,
#  1566,
#  1575,
#  1584,
#  1593,
#  1602,
#  1611,
#  1620,
#  1629,
#  1638,
#  1647,
#  1656,
#  1665,
#  1674,
#  1683,
#  1692,
#  1701,
#  1710,
#  1719,
#  1728,
#  1737,
#  1746,
#  1755,
#  1764,
#  1773,
#  1782,
#  1791,
#  1800,
#  1809,
#  1818,
#  1827,
#  1836]

# %%
for i in range(100):
    plt.plot(x_0[i])

# %%
def check_for_nan_or_inf(tensor):
    has_nan = tf.reduce_any(tf.math.is_nan(tensor))
    has_inf = tf.reduce_any(tf.math.is_inf(tensor))
    return has_nan, has_inf

# Assuming `dataset` is your tf.data.Dataset
for batch in batches:
    x, y = batch
    has_nan_x, has_inf_x = check_for_nan_or_inf(x)
    has_nan_y, has_inf_y = check_for_nan_or_inf(y)
    
    if has_nan_x or has_inf_x:
        print("Found NaN or Inf in input features")
    if has_nan_y or has_inf_y:
        print("Found NaN or Inf in input labels")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       4     return has_nan, has_inf
#       6 # Assuming `dataset` is your tf.data.Dataset
# ----> 7 for batch in batches:
#       8     x, y = batch
#       9     has_nan_x, has_inf_x = check_for_nan_or_inf(x)
#
# NameError: name 'batches' is not defined

# %%
# s_hat = cnn(x_0)
# plt.plot(s_hat[1,1,:])
plt.plot(y_0[0,0,:])
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plt.plot(y_0[1,0,:])

# %%
# Output for sisnr trained model for five epochs
fig, axes = plt.subplots(1,4, figsize=(12,4))
sources = ["Drums", "Bass", "Other", "Vocals"]

for i in range(4):
    axes[i].plot(x_0[0], label="Orignal Mix")
    axes[i].plot(y_0[0][i], label=f"Source")
    axes[i].plot(output_x_0[0][i], label=f"Source Est")

    if i==0:
        fig.legend()

    axes[i].set_title(f"Source: {sources[i]}")

# %%
cnn.load_weights("training_mse_0/cp.ckpt")

# %%
output_x_0 = cnn(x_0)

# %%
# Output for logl2 trained model for five epochs
fig, axes = plt.subplots(1,4, figsize=(12,4))
sources = ["Drums", "Bass", "Other", "Vocals"]

for i in range(4):
    axes[i].plot(x_0[0], label="Orignal Mix")
    axes[i].plot(y_0[0][i], label=f"Source")
    axes[i].plot(output_x_0[0][i], label=f"Source Est")

    if i==0:
        fig.legend()

    axes[i].set_title(f"Source: {sources[i]}")

# %%
# Output for mse trained model for five epochs

fig, axes = plt.subplots(1,4, figsize=(12,4))
sources = ["Drums", "Bass", "Other", "Vocals"]

for i in range(4):
    axes[i].plot(x_0[0], label="Orignal Mix")
    axes[i].plot(y_0[0][i], label=f"Source")
    axes[i].plot(output_x_0[0][i], label=f"Source Est")

    if i==0:
        fig.legend()

    axes[i].set_title(f"Source: {sources[i]}")

# %%
# Output for sdr trained model for five epochs

fig, axes = plt.subplots(1,4, figsize=(12,4))
sources = ["Drums", "Bass", "Other", "Vocals"]

for i in range(4):
    axes[i].plot(x_0[0], label="Orignal Mix")
    axes[i].plot(y_0[0][i], label=f"Source")
    axes[i].plot(output_x_0[0][i], label=f"Source Est")

    if i==0:
        fig.legend()

    axes[i].set_title(f"Source: {sources[i]}")

# %%
create_fit_save(dataset)
# Out:
# Epoch 1/8
# WARNING:tensorflow:Gradients do not exist for variables ['ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_96/kernel:0', 'ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_96/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_96/kernel:0', 'ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_96/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 4000/4000 [==============================] - ETA: 0s - loss: 1.4906 - accuracy: 0.3134
# Epoch 1: saving model to training_LOGL2_2\cp.ckpt
# 4000/4000 [==============================] - 2900s 717ms/step - loss: 1.4906 - accuracy: 0.3134
# Epoch 2/8
# 4000/4000 [==============================] - ETA: 0s - loss: 1.4869 - accuracy: 0.3145
# Epoch 2: saving model to training_LOGL2_2\cp.ckpt
# 4000/4000 [==============================] - 2887s 722ms/step - loss: 1.4869 - accuracy: 0.3145
# Epoch 3/8
# 4000/4000 [==============================] - ETA: 0s - loss: 1.4835 - accuracy: 0.3158
# Epoch 3: saving model to training_LOGL2_2\cp.ckpt
# 4000/4000 [==============================] - 2891s 723ms/step - loss: 1.4835 - accuracy: 0.3158
# Epoch 4/8
# 4000/4000 [==============================] - ETA: 0s - loss: 1.4802 - accuracy: 0.3164
# Epoch 4: saving model to training_LOGL2_2\cp.ckpt
# 4000/4000 [==============================] - 2889s 722ms/step - loss: 1.4802 - accuracy: 0.3164
# Epoch 5/8
# 4000/4000 [==============================] - ETA: 0s - loss: 1.4768 - accuracy: 0.3156
# Epoch 5: saving model to training_LOGL2_2\cp.ckpt
# 4000/4000 [==============================] - 2895s 724ms/step - loss: 1.4768 - accuracy: 0.3156
# Epoch 6/8
# 4000/4000 [==============================] - ETA: 0s - loss: 1.4736 - accuracy: 0.3162
# Epoch 6: saving model to training_LOGL2_2\cp.ckpt
# 4000/4000 [==============================] - 2884s 721ms/step - loss: 1.4736 - accuracy: 0.3162
# Epoch 7/8
# 4000/4000 [==============================] - ETA: 0s - loss: 1.4703 - accuracy: 0.3160
# Epoch 7: saving model to training_LOGL2_2\cp.ckpt
# 4000/4000 [==============================] - 2883s 721ms/step - loss: 1.4703 - accuracy: 0.3160
# Epoch 8/8
# 4000/4000 [==============================] - ETA: 0s - loss: 1.4671 - accuracy: 0.3153
# Epoch 8: saving model to training_LOGL2_2\cp.ckpt
# 4000/4000 [==============================] - 2883s 721ms/step - loss: 1.4671 - accuracy: 0.3153
# Epoch 1/10
# WARNING:tensorflow:Gradients do not exist for variables ['ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_195/kernel:0', 'ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_195/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_195/kernel:0', 'ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_195/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 4000/4000 [==============================] - ETA: 0s - loss: -2.8411 - accuracy: 0.2659
# Epoch 1: saving model to training_SDR_2\cp.ckpt
# 4000/4000 [==============================] - 2912s 721ms/step - loss: -2.8411 - accuracy: 0.2659
# Epoch 2/10
# 3130/4000 [======================>.......] - ETA: 10:28 - loss: -3.1291 - accuracy: 0.2820
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 create_fit_save(dataset)
#
# Cell In[3], line 26, in create_fit_save(dataset, epochs)
#      24 hist1 = run_model(cnn, "LOGL2", LOGL2(), dataset, epochs=8)
#      25 cnn = convtas.ConvTasNet(param)
# ---> 26 hist2 = run_model(cnn, "SDR", SDR(), dataset)
#      28 return hist1, hist2
#
# Cell In[3], line 16, in run_model(model, loss, loss_funct, dataset, epochs)
#       7 cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
#       8                                                 save_weights_only=True,
#       9                                                 verbose=1)
#      11 model.compile(optimizer='adam',
#      12           loss=loss_funct,
#      13           metrics=['accuracy']
#      14           )
# ---> 16 history = model.fit(dataset, epochs=epochs, callbacks=[cp_callback])
#      18 return history
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\keras\engine\training.py:1570, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1568 logs = tmp_logs
#    1569 end_step = step + data_handler.step_increment
# -> 1570 callbacks.on_train_batch_end(end_step, logs)
#    1571 if self.stop_training:
#    1572     break
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\keras\callbacks.py:470, in CallbackList.on_train_batch_end(self, batch, logs)
#     463 """Calls the `on_train_batch_end` methods of its callbacks.
#     464
#     465 Args:
#     466     batch: Integer, index of batch within the current epoch.
#     467     logs: Dict. Aggregated metric results up until this batch.
#     468 """
#     469 if self._should_call_train_batch_hooks:
# --> 470     self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\keras\callbacks.py:317, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     315     self._call_batch_begin_hook(mode, batch, logs)
#     316 elif hook == "end":
# --> 317     self._call_batch_end_hook(mode, batch, logs)
#     318 else:
#     319     raise ValueError(
#     320         f"Unrecognized hook: {hook}. "
#     321         'Expected values are ["begin", "end"]'
#     322     )
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\keras\callbacks.py:340, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     337     batch_time = time.time() - self._batch_start_time
#     338     self._batch_times.append(batch_time)
# --> 340 self._call_batch_hook_helper(hook_name, batch, logs)
#     342 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     343     end_hook_name = hook_name
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\keras\callbacks.py:388, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     386 for callback in self.callbacks:
#     387     hook = getattr(callback, hook_name)
# --> 388     hook(batch, logs)
#     390 if self._check_timing:
#     391     if hook_name not in self._hook_times:
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\keras\callbacks.py:1081, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1080 def on_train_batch_end(self, batch, logs=None):
# -> 1081     self._batch_update_progbar(batch, logs)
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\keras\callbacks.py:1157, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1153     self.seen += add_seen
#    1155 if self.verbose == 1:
#    1156     # Only block async when verbose = 1.
# -> 1157     logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1158     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\keras\utils\tf_utils.py:635, in sync_to_numpy_or_python_type(tensors)
#     632         return t
#     633     return t.item() if np.ndim(t) == 0 else t
# --> 635 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\tensorflow\python\util\nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\tensorflow\python\util\nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\keras\utils\tf_utils.py:628, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     625 def _to_single_numpy_or_python_type(t):
#     626     # Don't turn ragged or sparse tensors to NumPy.
#     627     if isinstance(t, tf.Tensor):
# --> 628         t = t.numpy()
#     629     # Strings, ragged and sparse tensors don't have .item(). Return them
#     630     # as-is.
#     631     if not isinstance(t, (np.ndarray, np.generic)):
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\tensorflow\python\framework\ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\tensorflow\python\framework\ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
cnn.compile(optimizer='adam',
              loss=SDR(),
              metrics=['accuracy']
              )

# %%
history = cnn.fit(dataset, epochs=10)
# Out:
# Epoch 1/10
# WARNING:tensorflow:Gradients do not exist for variables ['ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_96/kernel:0', 'ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_96/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_96/kernel:0', 'ConvTasNet/Separator/TemporalConv/Conv1DBlock/DepthwiseConv/conv1d_96/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 400/400 [==============================] - 1168s 3s/step - loss: -2.3059 - accuracy: 0.1951
# Epoch 2/10
# 400/400 [==============================] - 1174s 3s/step - loss: -2.8136 - accuracy: 0.2347
# Epoch 3/10
#  74/400 [====>.........................] - ETA: 3:41 - loss: -2.9191 - accuracy: 0.2421
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 history = cnn.fit(dataset, epochs=10)
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['loss'], label = 'MSE')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
class ConvTasNet(models.Model):
    """
    Full Conv-TasNet model, coded in TensorFlow. I heavily relied upon, upon Jane Wu's TensorFlow implementation (https://github.com/JaneWuNEU/Conv-TasNet-2)
    to get this to work. nplab's and kaituoxu's PyTorch implementations of the model were also instrumental for my understanding of the model.
    
    To explain what the model is doing in the most basic way, it takes a dataset of overlapping chunks of a audio in a waveform format then 
    encodes them using a simple 1D convolution. With this input data, the model is then put through several iterations of downsampling to get 
    features from the data. These features are then turned into separate masks for each target source in the audio data. Finally the masks are 
    applied to the orginal encoded data, which is finally put back into its orginal waveform data format with a Transpose 1D convolution.

    To understand the shape of the data throughout the model, I highly recommend looking at the Parameters class documentation, but I tried to 
    give documentation to the important paramters throughout the layers documentation as well. 
    """
    def __init__(self, param: Parameters):
        super().__init__(name="ConvTasNet")
        self.param = param


        self.encoder = Encoder(self.param)
        self.separator = Separator(self.param)
        self.decoder = Decoder(self.param)

    def call(self, x):
        w = self.encoder(x)
        m_i = self.separator(w)

        decoded = self.decoder(w, m_i)

        return decoded

# %%
param = Parameters(naplab_impl=True)

# %%
cnn = ConvTasNet(param)
output = cnn(data)

# %%
plt.plot(output[0,0,:])

# %%
class Encoder(layers.Layer):
    """ 
    First step of model not counting, preprocessing data. Puts the inputs through a 1D Convolutional layer with N output channels. The encoder also includes a activation
    function of a ReLU layer.

    Args: 
        N: Encoder output size
        win: Kernel size of encoder.

    """
    def __init__(self, param: Parameters):
        super(Encoder, self).__init__(name='Encoder')
        self.U = layers.Conv1D(param.N,param.win,strides=param.overlap,activation="relu",use_bias=False, data_format="channels_last")

    def call(self, x): # (M, T)
        batch_count,sample_count = x.shape
        x = tf.reshape(x, (batch_count, sample_count, 1)) # (M, T, 1)
        return self.U(x) # (M, K, N)

        
class Separator(layers.Layer):
    """ 
    To begin the we take the output of the encoder which we then normalize it and feed it into a 1x1Convolution.
    This layer repeats a Temporal Convolution Block multiple times, wherin, what is refered to as a Conv1D Block in the paper, is repeated
    several times for each instance of a Temporal Convolutional Block. Finally the output of the Temporal blocks is input into a 1x1 Convolution
    with C*N output channels.
    Args:
        N: (int) Encoder output size
        B: (int) Bottleneck Conv1DBlock output size
        R: (int) Amount of repeats of the Temporal Convolution block
        X: (int) Amount of times Conv1DBlock is applied in a Temporal Convolution block
        H: (int) Conv1DBlock input size
        C: (int) Amount of sources being estimated
        P: (int) Size of kernel in depthwise convolutions
    
    """
    def __init__(self, param: Parameters):
        super(Separator, self).__init__(name='Separator')
        self.C = param.C
        self.N = param.N
        self.skip=param.skip
        if param.casual:
            self.normalization = cLN(param.N)
        else:
            self.normalization = gLN(param.N) 
        self.bottle_neck = layers.Conv1D(param.B,1)
        
        self.temporal_conv = [TemporalConv(param.X, param.H, param.B, param.P, param.casual, skip=param.skip) for r in range(param.R)]
        self.skip_add = layers.Add()
        self.prelu = layers.PReLU()
        self.m_i = layers.Conv1D(param.C*param.N, 1)

    def call(self, w): # (M, K, N)
        M, K, _ = w.shape
        normalized_w = self.normalization(w) # (M, K, N)
        output = self.bottle_neck(normalized_w) # (M, K, B)
        if self.skip:
            skip_conn = tf.zeros(output.shape)
        for block in self.temporal_conv:
            if self.skip:
                output, skips = block(output)
                skip_conn = self.skip_add([skip_conn, skips])
            else:
                output = block(output)
        # (M, K, B)
        if self.skip:
            output = skip_conn

        output = self.prelu(output)
        estimated_masks = self.m_i(output) # (M, K, C*N)
        estimated_masks = activations.sigmoid(tf.reshape(estimated_masks, (M, self.C, K, self.N))) # (M, C, K, N)
        return estimated_masks
    
class Decoder(layers.Layer):
    """ 
    This is layer is final part of the model. Taking the features obtained, from the Conv1D blocks masks are finally combined into with the
    original mix into the estimated sources.

    Args:
        L : (int) length of individual chunks of audio.
    """
    def __init__(self, param: Parameters):
        super(Decoder, self).__init__(name='Decoder')
        self.C = param.C
        self.L = param.L
        self.N = param.N
        self.win = param.win
        self.naplab_impl = param.naplab_impl
        self.overlap = param.overlap

        if not self.naplab_impl:
            self.transpose_conv = layers.Conv1DTranspose(self.L,self.win,strides=param.overlap,use_bias=False)
        else:
            self.transpose_conv = layers.Conv1DTranspose(1,self.win,strides=param.overlap,use_bias=False)

    def call(self, w, m_i): # (M, K, N) (M, C, K, N)
        M,K,_, = w.shape

        w = tf.reshape(tf.repeat(w, 4, axis=0),m_i.shape) # (M, K, N) -> (M, C, K, N)
        output = w * m_i # (M, C, K, N) * (M, C, K, N) 
        output = self.transpose_conv(tf.reshape(output, (M*self.C, K, self.N))) # (M*C, T, 1) or (M*C, T, L)Okay so the official naplab implementation turns the encoded sources directly back into its wavform essentially 
                                                                                # but the kaituoxo one seems to turn it into a 16 channel output then subsetting to only take the first chunk to deal with overlap
        if self.naplab_impl:
            output = output[:,:,:self.overlap]
        output = tf.reshape(output, (M,self.C,-1)) # (M, C, T)
        return output

# %%
def make_base_dataset(M=1,T=320008):
    root_mus = '../MUSDB18'
    mus = musdb.DB(root=root_mus, subsets="train")
    song_list=[]
    for m in range(M):
        track = mus[m]
        audio_l,audio_r = track.audio[:T].T
        song_list.extend([audio_l,audio_r])
    
    return np.array(song_list)

data = make_base_dataset(T = 44100*4)

data.shape
# Out:
# (2, 176400)

# %%
x, y = datasets.load_unpack_tensordata()

# %%
x_0 = tf.reshape(x[0],(200, 40*16))
x_0.shape
# Out:
# TensorShape([200, 640])

# %%
param = Parameters()

# %%
param.win // 2
del data

# %%
encoder = Encoder(param)
w = encoder(x_0)
w.shape
# Out:
# TensorShape([50, 499, 512])

# %%
depthwise = DepthwiseConv(param.H, param.B, param.P, dilation=2, casual=True, skip=param.skip)
convblock = Conv1DBlock(param.H, param.B, param.P, dilation=2, casual=True)

# %%
sep = Separator(param)
output = sep(w)

# %%
decoder = Decoder(param)
decoded = decoder(w, output)
decoded.shape
# Out:
# Mask multi (200, 4, 79, 512)
# transpose conv (800, 640, 1)
# TensorShape([200, 4, 640])

# %%
output.shape
# Out:
# TensorShape([200, 4, 79, 512])

# %%
root_mus = '../MUSDB18'
mus = musdb.DB(root=root_mus, subsets="train")

# %%
audio_l,audio_r =mus[0].audio[:320000].T
audio_l.shape
# Out:
# (320000,)

# %% [markdown]
# ## Overall Architecture
#
# Looking at the model from a top down view, the data follows this pipeline:
#
# Data ---> Encoder ----> Separator ---> Decoder ---> Create Sources

# %%
# Params as globals for testing purposes
M=200
K=40
L=16 # Chunk size
C=4 # Amount of sources being estimated
N=512 # Encoder output size
B=128 # Conv1DBlock output size
H=512 # Conv1DBlock input size
P=3
R=3 # Amount of repeats of the Temporal Convolution block
X=8 # Amount of times Conv1DBlock is applied in a Temporal Convolution block
T=3000 # TODO: figure out how to get this param
dilation = 1
overlap=8
casual=False

# %%
class ConvTasNet(models.Model):
    """
    
    """
    def __init__(self,
                 L: int=16, # Chunk size
                 C: int=4, # Amount of sources being estimated
                 N: int=512, # Encoder output size
                 B: int=128, # Conv1DBlock output size
                 H: int=512, # Conv1DBlock input size
                 P: int=3, # Kernel size of Conv1DBlocks
                 R: int=3, # Amount of repeats of the Temporal Convolution block
                 X: int=8, # Amount of times Conv1DBlock is applied in a Temporal Convolution block
                 T: int=3000, # TODO: figure out how to get this param
                 # win: int=2, # Size of encoder-decoder kernels
                 overlap: int=8,
                 skip: bool=True,
                 casual: bool=False
                ):
        super().__init__(name="ConvTasNet")
        self.L = L
        self.C = C
        self.N = N
        self.B = B
        self.H = H
        self.R = R
        self.X = X
        self.T = T
        self.P = P
        # self.win = win
        self.overlap = overlap
        self.skip = skip
        self.casual = casual


        self.encoder = Encoder(self.N)
        self.separator = Separator(self.N, self.B, self.R, self.X, self.H, self.C, self.P, self.casual, self.skip)
        self.decoder = Decoder(self.L)

    def call(self, x):
        w = self.encoder(x)
        m_i = self.separator(w)

        decoded = self.decoder(m_i, w)

        return decoded

# %%
cnn = ConvTasNet()
cnn_output = cnn(x_batches[0])
cnn_output.shape
# Out:
# TensorShape([200, 4, 40, 16])

# %%
class Conv1DBlock(layers.Layer):
    def __init__(self, H, B, P, dilation, casual, skip = True):
        super(Conv1DBlock, self).__init__(name='Conv1DBlock')
        self.skip = skip
        self.input_channels = layers.Conv1D(H,1)
        self.prelu = layers.PReLU()
        if casual:
            self.norm = cLN(H)
        else:
            self.norm = gLN(H)
        
        self.depthwise = DepthwiseConv(H, B, P, dilation, casual, skip=self.skip)

    def call(self, input):
        input_channels = self.input_channels(input)
        input_channels = self.prelu(input_channels)
        input_channels = self.norm(input_channels)
        if self.skip:
            res, skip = self.depthwise(input_channels)
            return res, skip

        res = self.depthwise(input_channels, skip=self.skip)
        return res

class DepthwiseConv(layers.Layer):
    def __init__(self, H, B, P, dilation, casual, skip=True):
        super(DepthwiseConv, self).__init__(name='DepthwiseConv')
        self.skip = skip
        if casual:
            padding_type = "causal"
            self.norm = cLN(H)
        else:
            padding_type = "same"
            self.norm = gLN(H)

        self.conv1d = layers.Conv1D(H, P, dilation_rate=dilation, padding=padding_type, groups=H)
        self.prelu = layers.PReLU()
        
        self.res_out = layers.Conv1D(B, 1)
        if self.skip:
            self.skip_out = layers.Conv1D(B, 1)
    
    def call(self, input):
        input = self.conv1d(input) 
        input = self.prelu(input)
        input = self.norm(input)
        res = self.res_out(input)
        if self.skip:
            skip_out = self.skip_out(input)
            return res, skip_out
        
        return res

class TemporalConv(layers.Layer):
    def __init__(self, X, H, B, P, casual, skip=True):
        super(TemporalConv,self).__init__(name='TemporalConv')
        self.skip=skip
        self.blocks = []
        for i in range(X):
            dilation = 2 ** i
            self.blocks += [Conv1DBlock(H, B, P, dilation, casual, skip=self.skip)]
        self.res_add = layers.Add()
        self.skip_add = layers.Add()
    
    def call(self, block_input):
        if self.skip:
            skip_conn = tf.zeros(block_input.shape)
        for block in self.blocks:    
                if self.skip:
                    res, skip = block(block_input)
                    block_input = self.res_add([block_input, res])
                    skip_conn = self.skip_add([skip_conn,skip])
                else:
                    res = block(block_input)
                    block_input = self.res_add([block_input, res])
        if self.skip:
            return block_input, skip_conn
        return block_input

# %%
class Conv1DBlock(layers.Layer):
    def __init__(self, H, B, P, dilation, casual, skip = True):
        super(Conv1DBlock, self).__init__(name='Conv1DBlock')
        self.skip = skip
        self.input_channels = layers.Conv1D(H,1)
        self.prelu = layers.PReLU()
        if casual:
            self.norm = cLN(H)
        else:
            self.norm = gLN(H)
        
        self.depthwise = DepthwiseConv(H, B, P, dilation, casual, skip=self.skip)

    def call(self, input):
        input_channels = self.input_channels(input)
        input_channels = self.prelu(input_channels)
        input_channels = self.norm(input_channels)
        if self.skip:
            res, skip = self.depthwise(input_channels)
            return res, skip

        res = self.depthwise(input_channels, skip=self.skip)
        return res

class DepthwiseConv(layers.Layer):
    def __init__(self, H, B, P, dilation, casual, skip=True):
        super(DepthwiseConv, self).__init__(name='DepthwiseConv')
        self.skip = skip
        if casual:
            padding_type = "causal"
            self.norm = cLN(H)
        else:
            padding_type = "same"
            self.norm = gLN(H)

        self.conv1d = layers.Conv1D(H, P, dilation_rate=dilation, padding=padding_type, groups=H)
        self.prelu = layers.PReLU()
        
        self.res_out = layers.Conv1D(B, 1)
        if self.skip:
            self.skip_out = layers.Conv1D(B, 1)
    
    def call(self, input):
        input = self.conv1d(input) 
        input = self.prelu(input)
        input = self.norm(input)
        res = self.res_out(input)
        if self.skip:
            skip_out = self.skip_out(input)
            return res, skip_out
        
        return res

class TemporalConv(layers.Layer):
    def __init__(self, X, H, B, P, casual, skip=True):
        super(TemporalConv,self).__init__(name='TemporalConv')
        self.skip=skip
        self.blocks = []
        for i in range(X):
            dilation = 2 ** i
            self.blocks += [Conv1DBlock(H, B, P, dilation, casual, skip=self.skip)]
        self.res_add = layers.Add()
        self.skip_add = layers.Add()
    
    def call(self, block_input):
        skip_list = []
        for block in self.blocks:    
                if self.skip:
                    res, skip = block(block_input)
                    block_input = self.res_add([block_input, res])
                    skip_list.append(skip)
                else:
                    res = block(block_input)
                    block_input = self.res_add([block_input, res])
        if self.skip:
            skip_conn = self.skip_add(skip_list)
            return block_input, skip_conn
        return block_input

# %%
sep = Separator(param.N,param.B,param.R,param.X,param.H,param.C,param.P,True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 4
#       2 convblock = Conv1DBlock(param.H, param.B, param.P, dilation=2, casual=True)
#       3 tempconv = TemporalConv(param.X, param.H, param.B, param.P, casual=True)
# ----> 4 sep = Separator(param.N,param.B,param.R,param.X,param.H,param.C,param.P,True)
#
# TypeError: __init__() takes 2 positional arguments but 9 were given

# %%
dep_res,dep_out = depthwise(w)
print(dep_out.shape, dep_res.shape)
# Out:
# (6, 40000, 128) (6, 40000, 128)

# %%
conv_out = convblock(w)
conv_out[0].shape
# Out:
# TensorShape([6, 40000, 128])

# %%
temp_out = tempconv(w)
temp_conv.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 temp_out = tempconv(w)
#       2 temp_conv.shape
#
# File c:\Users\cobyw\anaconda3\envs\mss_project\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# Cell In[32], line 70, in TemporalConv.call(self, block_input)
#      68 if self.skip:
#      69     res, skip = block(block_input)
# ---> 70     block_input = self.res_add([block_input, res])
#      71     skip_list.append(skip)
#      72 else:
#
# ValueError: Exception encountered when calling layer "TemporalConv" "                 f"(type TemporalConv).
#
# Inputs have incompatible shapes. Received shapes (40000, 512) and (40000, 128)
#
# Call arguments received by layer "TemporalConv" "                 f"(type TemporalConv):
#   • block_input=tf.Tensor(shape=(6, 40000, 512), dtype=float32)

# %%
def choose_norm(casual, H):
    """ 
    Chooses normalization type based on value of casual.

    Args:
        casual: (bool) chooses type of normalization applied.
    Returns:
        cLN or gLN (layer)
    """
    if casual:
        return cLN(H)
    else:
        return gLN(H)

class cLN(layers.Layer):
    def __init__(self, H, EPS = 1e-8):
        super(cLN, self).__init__(name="cLN")
        self.EPS = EPS
        shape = (1,1,H)
        self.gamma = tf.Variable(tf.ones(shape),trainable=True,shape=shape)
        self.beta = tf.Variable(tf.zeros(shape),trainable=True,shape=shape)

    def call(self, input):
        # (M, K, H)
        E_f = tf.math.reduce_mean(input, axis=2, keepdims=True) # (M, K, 1)
        var = tf.math.reduce_variance(input, axis=2, keepdims=True)# (M, K, 1)

        normalized = self.gamma * (input - E_f) / tf.math.sqrt(var + self.EPS) + self.beta
        # (M, K, H)
        return normalized
    
class gLN(layers.Layer):
    def __init__(self, H, EPS = 1e-8):
        super(gLN, self).__init__(name="gLN")
        self.EPS = EPS
        shape = (1,1,H)
        self.gamma = tf.Variable(tf.ones(shape),trainable=True,shape=shape)
        self.beta = tf.Variable(tf.zeros(shape),trainable=True,shape=shape)

    def call(self, input):
        # (M, K, H)
        E_f = tf.math.reduce_mean(input, axis=(1,2), keepdims=True) # (M, 1, 1)
        var = tf.math.reduce_variance(input, axis=(1,2), keepdims=True)# (M, 1, 1)

        normalized = self.gamma * (input - E_f) / tf.math.sqrt(var + self.EPS) + self.beta
        # (M, K, H)
        return normalized

# %%
def show_norm(input):
    fig, axes = plt.subplots(1,3, figsize=(12, 4))

    norm_c = cLN(H)(input)
    norm_g = gLN(H)(input)

    axes[0].set_title("Not normalized")
    axes[0].plot(input[0][0])

    axes[1].set_title("Casual normalization")
    axes[1].plot(norm_c[0][0])

    axes[2].set_title("Global normalization")
    axes[2].plot(norm_g[0][0])

# %%
show_norm(test_encoded)
